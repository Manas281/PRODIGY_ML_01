# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Load your training data
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
# Feature engineering (combine relevant square footage and bathroom columns)
# Consider feature importance and potential correlations
total_bathrooms = train_data["FullBath"] + 0.5 * train_data["HalfBath"] + train_data["BsmtFullBath"] + 0.5 * train_data["BsmtHalfBath"]
train_data["total_bathrooms"] = total_bathrooms

total_square_footage = train_data["1stFlrSF"] + train_data["2ndFlrSF"] + train_data["TotalBsmtSF"]
train_data["total_square_footage"] = total_square_footage

# Repeat feature engineering for test data
total_bathrooms = test_data["FullBath"] + 0.5 * test_data["HalfBath"] + test_data["BsmtFullBath"] + 0.5 * test_data["BsmtHalfBath"]
test_data["total_bathrooms"] = total_bathrooms

total_square_footage = test_data["1stFlrSF"] + test_data["2ndFlrSF"] + test_data["TotalBsmtSF"]
test_data["total_square_footage"] = total_square_footage

# %%
# Feature selection (consider additional relevant features)
bathrooms = ["BsmtFullBath", "BsmtHalfBath", "FullBath", "HalfBath"]
square_foot = ["1stFlrSF", "2ndFlrSF", "TotalBsmtSF"]
bedrooms = ["BedroomAbvGr", "TotRmsAbvGrd"]
features = ["LotArea", "bedrooms", "bathrooms"]  # Adjust based on your data
target = "price"  # Replace with your price column name

# %%
# Feature selection
features = ["total_square_footage", "BedroomAbvGr", "TotRmsAbvGrd", "total_bathrooms"]  # Adjust based on analysis
target = "SalePrice"  # Replace with your price column name

# %%
# Impute numerical columns with mean (excluding identified string columns)
train_data = train_data.fillna(train_data.mean(skipna=True), inplace=False)  # Avoid modifying original data
test_data = test_data.fillna(test_data.mean(skipna=True), inplace=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Impute numerical columns with mean (excluding identified string columns)
# ----> 2 train_data = train_data.fillna(train_data.mean(skipna=True), inplace=False)  # Avoid modifying original data
#       3 test_data = test_data.fillna(test_data.mean(skipna=True), inplace=False)
#
# File ~/Desktop/Manas Project /env/lib/python3.12/site-packages/pandas/core/frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# ...

# %%
# Handle missing values (if any)
# Explore appropriate imputation techniques based on data characteristics
train_data = train_data.fillna(train_data.mean())  # Simple mean imputation (replace with better methods)
test_data = test_data.fillna(test_data.mean())  # Simple mean imputation (replace with better methods)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 # Handle missing values (if any)
#       2 # Explore appropriate imputation techniques based on data characteristics
# ----> 3 train_data = train_data.fillna(train_data.mean())  # Simple mean imputation (replace with better methods)
#       4 test_data = test_data.fillna(test_data.mean())  # Simple mean imputation (replace with better methods)
#
# File ~/Desktop/Manas Project /env/lib/python3.12/site-packages/pandas/core/frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
# ...

# %%
# Split training data into training and testing sets within the training data
X_train, X_val, y_train, y_val = train_test_split(train_data[features], train_data[target], test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_val)

# %%
# Evaluate model performance (consider multiple metrics beyond MSE)
mse = mean_squared_error(y_val, y_pred)
print("Mean Squared Error on validation set:", mse)
# Out:
# Mean Squared Error on validation set: 2081232832.946819

# %%
# Make predictions on the testing data using the trained model
test_predictions = model.predict(test_data[features])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Make predictions on the testing data using the trained model
# ----> 2 test_predictions = model.predict(test_data[features])
#
# File ~/Desktop/Manas Project /env/lib/python3.12/site-packages/sklearn/linear_model/_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~/Desktop/Manas Project /env/lib/python3.12/site-packages/sklearn/linear_model/_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# ...
